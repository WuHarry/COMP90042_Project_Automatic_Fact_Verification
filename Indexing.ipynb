# %%
"""
Basic indexing and searching example adapted from http://lucene.apache.org/core/7_2_0/core/index.html
"""
INDEX_DIR = "IndexFiles.index"

import sys, os, lucene, time, threading, unicodedata, re, codecs
from zipfile import ZipFile
from datetime import datetime

from java.nio.file import Paths
from org.apache.lucene.analysis.miscellaneous import LimitTokenCountAnalyzer
from org.apache.lucene.analysis.standard import StandardAnalyzer
from org.apache.lucene.document import Document, Field, FieldType
from org.apache.lucene.index import FieldInfo, IndexWriter, IndexWriterConfig, IndexOptions
from org.apache.lucene.store import SimpleFSDirectory

class Ticker(object):

    def __init__(self):
        self.tick = True

    def run(self):
        while self.tick:
            sys.stdout.write('.')
            sys.stdout.flush()
            time.sleep(1.0)

            
class IndexFiles(object):
    """Usage: python IndexFiles <doc_directory>"""

    def __init__(self, root, storeDir, analyzer):

        if not os.path.exists(storeDir):
            os.mkdir(storeDir)
        
        store = SimpleFSDirectory(Paths.get(storeDir))

        analyzer = LimitTokenCountAnalyzer(analyzer, 1048576)
        config = IndexWriterConfig(analyzer)
        config.setOpenMode(IndexWriterConfig.OpenMode.CREATE)
        writer = IndexWriter(store, config)

        self.indexDocs(root, writer)
        ticker = Ticker()
        print("commit index")
        threading.Thread(target=ticker.run).start()
        writer.commit()
        writer.close()
        ticker.tick = False
        print("done")

    def indexDocs(self, root, writer):

        t1 = FieldType()
        t1.setStored(True)
        t1.setTokenized(True)
        t1.setIndexOptions(IndexOptions.DOCS_AND_FREQS)
        
        wikiFile = ZipFile(root, 'r')
        files = wikiFile.namelist()
        
        i = 0
        for file in files[1:]:
            i += 1
            wiki = wikiFile.open(file,'r')
            for line in wiki:
                for line in codecs.iterdecode(wiki, 'utf8'):
                    normailized = unicodedata.normalize('NFD', line).split(' ', 2)
                    if not normailized[1].isdigit(): continue
                    docname = normailized[0] + ' ' + normailized[1]
                    name = re.sub(r'[^a-zA-Z0-9]', ' ', normailized[0])
                    contents = normailized[2]
                    doc = Document()
                    doc.add(Field('docname', docname, t1))
                    doc.add(Field('name', name, t1))
                    doc.add(Field('contents', contents, t1))
                    writer.addDocument(doc)
            print('File %d done indexing' % i, file)
            
if __name__ == '__main__':
    assert lucene.getVMEnv() or lucene.initVM(vmargs=['-Djava.awt.headless=true'])
    print('lucene', lucene.VERSION)
    start = datetime.now()
    try:
        base_dir = os.getcwd()
        IndexFiles('wiki-pages-text.zip', os.path.join(base_dir, INDEX_DIR), StandardAnalyzer())
        end = datetime.now()
        print(end - start)
    except Exception as e:
        print("Failed: ", str(e))
# Out:
# lucene 7.7.1
# File 1 done indexing wiki-pages-text/wiki-009.txt
# File 2 done indexing wiki-pages-text/wiki-021.txt
# File 3 done indexing wiki-pages-text/wiki-035.txt
# File 4 done indexing wiki-pages-text/wiki-034.txt
# File 5 done indexing wiki-pages-text/wiki-020.txt
# File 58 done indexing wiki-pages-text/wiki-046.txt
# File 59 done indexing wiki-pages-text/wiki-063.txt
# File 60 done indexing wiki-pages-text/wiki-077.txt
# File 61 done indexing wiki-pages-text/wiki-088.txt
# File 62 done indexing wiki-pages-text/wiki-103.txt
# File 63 done indexing wiki-pages-text/wiki-102.txt
# File 64 done indexing wiki-pages-text/wiki-089.txt
# File 65 done indexing wiki-pages-text/wiki-076.txt
# File 66 done indexing wiki-pages-text/wiki-062.txt
# File 67 done indexing wiki-pages-text/wiki-048.txt
# File 68 done indexing wiki-pages-text/wiki-074.txt
# File 69 done indexing wiki-pages-text/wiki-060.txt
# File 70 done indexing wiki-pages-text/wiki-100.txt
# File 71 done indexing wiki-pages-text/wiki-101.txt
# File 72 done indexing wiki-pages-text/wiki-061.txt
# File 73 done indexing wiki-pages-text/wiki-075.txt
# File 74 done indexing wiki-pages-text/wiki-049.txt
# File 75 done indexing wiki-pages-text/wiki-071.txt
# File 76 done indexing wiki-pages-text/wiki-065.txt
# File 77 done indexing wiki-pages-text/wiki-059.txt
# File 78 done indexing wiki-pages-text/wiki-105.txt
# File 79 done indexing wiki-pages-text/wiki-104.txt
# File 80 done indexing wiki-pages-text/wiki-058.txt
# File 81 done indexing wiki-pages-text/wiki-064.txt
# File 82 done indexing wiki-pages-text/wiki-070.txt
# File 83 done indexing wiki-pages-text/wiki-066.txt
# File 84 done indexing wiki-pages-text/wiki-072.txt
# File 85 done indexing wiki-pages-text/wiki-099.txt
# File 86 done indexing wiki-pages-text/wiki-106.txt
# File 87 done indexing wiki-pages-text/wiki-107.txt
# File 88 done indexing wiki-pages-text/wiki-098.txt
# File 89 done indexing wiki-pages-text/wiki-073.txt
# File 90 done indexing wiki-pages-text/wiki-067.txt
# File 91 done indexing wiki-pages-text/wiki-028.txt
# File 92 done indexing wiki-pages-text/wiki-014.txt
# File 93 done indexing wiki-pages-text/wiki-015.txt
# File 94 done indexing wiki-pages-text/wiki-001.txt
# File 95 done indexing wiki-pages-text/wiki-029.txt
# File 96 done indexing wiki-pages-text/wiki-017.txt
# File 97 done indexing wiki-pages-text/wiki-003.txt
# File 98 done indexing wiki-pages-text/wiki-002.txt
# File 99 done indexing wiki-pages-text/wiki-016.txt
# File 100 done indexing wiki-pages-text/wiki-012.txt
# File 101 done indexing wiki-pages-text/wiki-006.txt
# File 102 done indexing wiki-pages-text/wiki-007.txt
# File 103 done indexing wiki-pages-text/wiki-013.txt
# File 104 done indexing wiki-pages-text/wiki-005.txt
# File 105 done indexing wiki-pages-text/wiki-011.txt
# File 106 done indexing wiki-pages-text/wiki-039.txt
# File 107 done indexing wiki-pages-text/wiki-038.txt
# File 108 done indexing wiki-pages-text/wiki-010.txt
# File 109 done indexing wiki-pages-text/wiki-004.txt
# commit index
# ........................done
# 0:16:22.673606
